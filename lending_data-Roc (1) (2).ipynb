# %% [markdown]
# # Customer Loan Prediction- Using Various Classification Technique
#
# ## Overview
#
# In this project we have put ourself in the shoes of a loan issuer and manage credit risk by using the past data and deciding whom to give the loan to in the future. The dataset contain complete loan data for all loans issued by XYZ Corp through 2007-2015. The data contains the indicator of default, payment information, credit history, etc.
#
# ## Objective
#
# To build a data model to predict the probability of default, and choose a cut-off based on what is suitable. Alternatively to use a modelling technique which gives binary output.
# Following steps to be done:
# Based on the data that is available during loan application, build a model to predict default in the future. This will help the company in deciding whether or not to pass the loan.
# Also the data contains defaulters, successful payers and customers who were current during that time. To simplify the problem, customers under 'current' status have been considered as non-defaulters in the dataset.
#
# ## Data Given
#
# * addr_state:- The state provided by the borrower in the loan application
# * annual_inc:- The self-reported annual income provided by the borrower during registration
# * annual_inc_joint:- The combined self-reported annual income provided by the co-borrowers during registration
# * application_type:- Indicates whether the loan is an individual application or a joint application with two co-borrowers
# * collection_recovery_fee:- post charge off collection fee
# * collections_12_mths_ex_med:- Number of collections in 12 months excluding medical collections
# * delinq_2yrs:- The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years
# * desc:- Loan description provided by the borrower
# * dti:- A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage           and the requested loan, divided by the borrower’s self-reported monthly income.
# * dti_joint:- A ratio calculated using the co-borrowers' total monthly payments on the total debt obligations, excluding                       mortgages and the requested loan, divided by the co-borrowers' combined self-reported monthly income
# * earliest_cr_line:- The month the borrower's earliest reported credit line was opened
# * emp_length:- Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means                  ten or more years.
# * emp_title:- The job title supplied by the Borrower when applying for the loan.
# * funded_amnt:- The total amount committed to that loan at that point in time.
# * funded_amnt_inv:- The total amount committed by investors for that loan at that point in time.
# * grade:- XYZ corp. assigned loan grade
# * home_ownership:- The home ownership status provided by the borrower during registration. Our values are: RENT, OWN, MORTGAGE,                    OTHER.
# * id:- A unique assigned ID for the loan listing.
# * initial_list_status:- The initial listing status of the loan. Possible values are – W, F
# * inq_last_6mths:- The number of inquiries in past 6 months (excluding auto and mortgage inquiries)
# * installment:- The monthly payment owed by the borrower if the loan originates.
# * int_rate:- Interest Rate on the loan
# * issue_d:- The month which the loan was funded
# * last_credit_pull_d:- The most recent month XYZ corp. pulled credit for this loan
# * last_pymnt_amnt:- Last total payment amount received
# * last_pymnt_d:- Last month payment was received
# * loan_amnt:- The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces               the loan amount, then it will be reflected in this value.
# * loan_status:- Current status of the loan
# * member_id:- A unique Id for the borrower member.
# * mths_since_last_delinq:- The number of months since the borrower's last delinquency.
# * mths_since_last_major_derog:- Months since most recent 90-day or worse rating
# * mths_since_last_record:- The number of months since the last public record.
# * next_pymnt_d:- Next scheduled payment date
# * open_acc:- The number of open credit lines in the borrower's credit file.
# * out_prncp:- Remaining outstanding principal for total amount funded
# * out_prncp_inv:- Remaining outstanding principal for portion of total amount funded by investors
# * policy_code:- publicly available policy_code=1,new products not publicly available policy_code=2
# * pub_rec:- Number of derogatory public records
# * purpose:- A category provided by the borrower for the loan request.
# * pymnt_plan:- Indicates if a payment plan has been put in place for the loan
# * recoveries:- post charge off gross recovery
# * revol_bal:- Total credit revolving balance
# * revol_util:- Revolving line utilization rate, or the amount of credit the borrower is using relative to all available                        revolving credit.
# * sub_grade:- XYZ assigned assigned loan subgrade
# * term:- The number of payments on the loan. Values are in months and can be either 36 or 60.
# * title:- The loan title provided by the borrower
# * total_acc:- The total number of credit lines currently in the borrower's credit file
# * total_pymnt:- Payments received to date for total amount funded
# * total_pymnt_inv:- Payments received to date for portion of total amount funded by investors
# * total_rec_int:- Interest received to date
# * total_rec_late_fee:- Late fees received to date
# * total_rec_prncp:- Principal received to date
# * verified_status_joint:- Indicates if the co-borrowers' joint income was verified by XYZ corp., not verified, or if the income                           source was verified
# * zip_code:- The first 3 numbers of the zip code provided by the borrower in the loan application.
# * open_acc_6m:- Number of open trades in last 6 months
# * open_il_6m:- Number of currently active installment trades
# * open_il_12m:- Number of installment accounts opened in past 12 months
# * open_il_24m:- Number of installment accounts opened in past 24 months
# * mths_since_rcnt_il:- Months since most recent installment accounts opened
# * total_bal_il:- Total current balance of all installment accounts
# * il_util:- Ratio of total current balance to high credit/credit limit on all install acct
# * open_rv_12m:- Number of revolving trades opened in past 12 months
# * open_rv_24m:- Number of revolving trades opened in past 24 months
# * max_bal_bc:- Maximum current balance owed on all revolving accounts
# * all_util:- Balance to credit limit on all trades
# * total_rev_hi_lim:- Total revolving high credit/credit limit
# * inq_fi:- Number of personal finance inquiries
# * total_cu_tl:- Number of finance trades
# * inq_last_12m:- Number of credit inquiries in past 12 months
# * acc_now_delinq:- The number of accounts on which the borrower is now delinquent
# * tot_coll_amt:- Total collection amounts ever owed
# * tot_cur_bal:- Total current balance of all accounts
# * verification_status:- Was the income source verified

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
loan = pd.read_csv(r"E:\python\XYZCorp.csv", sep = "\t",parse_dates=['issue_d'] )
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (17,45,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# 2     15.96        84.33     C        C5  ...     NaN         NaN         NaN
# 3     13.49       339.31     C        C1  ...     NaN         NaN         NaN
# 4     12.69        67.79     B        B5  ...     NaN         NaN         NaN
#
# ...

# %%
loan_1 = loan.copy()

# %%
# to see all columns when using describe function
pd.set_option("display.max_columns",80)
pd.set_option("display.max_rows",80)    # set default number of rows to be displayed

# %%
loan.shape
# Out:
# (855969, 73)

# %%
loan.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code',
#        'addr_state', 'dti', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'mths_since_last_delinq', 'mths_since_last_record',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'annual_inc_joint', 'dti_joint',
# ...

# %% [markdown]
# ## Pre-Processing

# %%
loan.info()   #describe individual attributes by data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 73 columns):
# id                             855969 non-null int64
# member_id                      855969 non-null int64
# loan_amnt                      855969 non-null float64
# funded_amnt                    855969 non-null float64
# funded_amnt_inv                855969 non-null float64
# term                           855969 non-null object
# int_rate                       855969 non-null float64
# installment                    855969 non-null float64
# grade                          855969 non-null object
# sub_grade                      855969 non-null object
# emp_title                      806526 non-null object
# emp_length                     812908 non-null object
# home_ownership                 855969 non-null object
# annual_inc                     855969 non-null float64
# verification_status            855969 non-null object
# ...

# %%
loan.describe(include = "all")
# Out:
#                   id     member_id      loan_amnt    funded_amnt  \
# count   8.559690e+05  8.559690e+05  855969.000000  855969.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# first            NaN           NaN            NaN            NaN
# last             NaN           NaN            NaN            NaN
# mean    3.224073e+07  3.476269e+07   14745.571335   14732.378305
# std     2.271969e+07  2.399418e+07    8425.340005    8419.471653
# min     5.473400e+04  7.069900e+04     500.000000     500.000000
# 25%     9.067986e+06  1.079273e+07    8000.000000    8000.000000
# 50%     3.431355e+07  3.697532e+07   13000.000000   13000.000000
# 75%     5.446311e+07  5.803559e+07   20000.000000   20000.000000
# max     6.861687e+07  7.351969e+07   35000.000000   35000.000000
#
# ...

# %%
loan.drop(["id", "member_id"], axis = 1, inplace = True)   # unique value columns

# %%
loan.policy_code.value_counts(normalize = True) * 100     # majority of  records have the same value....attribute is biased
# Out:
# 1.0    100.0
# Name: policy_code, dtype: float64

# %%
loan.drop(["policy_code"], axis =1, inplace = True)

# %%
for i in loan.select_dtypes(include = ["object"]):
    print(loan[i].value_counts(normalize = True) * 100)
    print("\n")
# Out:
#  36 months    70.121815
#  60 months    29.878185
# Name: term, dtype: float64
#
#
# B    28.972778
# C    27.670979
# A    17.017556
# D    15.514814
# E     7.762898
# F     2.491679
# G     0.569296
# Name: grade, dtype: float64
#
#
# B3    6.420560
# B4    6.322192
# C1    6.026854
# C2    5.894723
# C3    5.647050
# B2    5.559664
# B5    5.529756
# C4    5.483960
# B1    5.140607
# A5    5.135350
# C5    4.618392
# D1    4.050030
# A4    3.971055
# D2    3.316125
# D3    2.954429
# D4    2.833397
# A3    2.698112
# A1    2.630469
# A2    2.582570
# D5    2.360833
# E1    2.012923
# E2    1.868526
# E3    1.553094
# E4    1.286378
# E5    1.041977
# F1    0.782972
# F2    0.581680
# F3    0.478872
# F4    0.370107
# F5    0.278047
# G1    0.198372
# G2    0.147085
# G3    0.102457
# G4    0.066591
# G5    0.054792
# Name: sub_grade, dtype: float64
#
#
# Teacher                                     1.607512
# Manager                                     1.341680
# ...

# %%
loan.drop(["pymnt_plan", "zip_code", "application_type"], axis = 1, inplace = True)

# %%
percent_missing = loan.isnull().sum() * 100 / len(loan)
missing_value_df = pd.DataFrame({'column_name': loan.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', ascending = False , inplace=True)

# %%
missing_value_df1 = missing_value_df[missing_value_df.percent_missing > 75]

# %%
loan.drop(missing_value_df1.index, axis = 1, inplace = True)

# %%
loan.describe(include = "all")
# Out:
#             loan_amnt    funded_amnt  funded_amnt_inv        term  \
# count   855969.000000  855969.000000    855969.000000      855969
# unique            NaN            NaN              NaN           2
# top               NaN            NaN              NaN   36 months
# freq              NaN            NaN              NaN      600221
# first             NaN            NaN              NaN         NaN
# last              NaN            NaN              NaN         NaN
# mean     14745.571335   14732.378305     14700.061226         NaN
# std       8425.340005    8419.471653      8425.805478         NaN
# min        500.000000     500.000000         0.000000         NaN
# 25%       8000.000000    8000.000000      8000.000000         NaN
# 50%      13000.000000   13000.000000     13000.000000         NaN
# 75%      20000.000000   20000.000000     20000.000000         NaN
# max      35000.000000   35000.000000     35000.000000         NaN
#
# ...

# %%
loan.isnull().sum()
# Out:
# loan_amnt                          0
# funded_amnt                        0
# funded_amnt_inv                    0
# term                               0
# int_rate                           0
# installment                        0
# grade                              0
# sub_grade                          0
# emp_title                      49443
# emp_length                     43061
# home_ownership                     0
# annual_inc                         0
# verification_status                0
# issue_d                            0
# purpose                            0
# title                             33
# addr_state                         0
# dti                                0
# delinq_2yrs                        0
# earliest_cr_line                   0
# inq_last_6mths                     0
# mths_since_last_delinq        439812
# open_acc                           0
# pub_rec                            0
# revol_bal                          0
# ...

# %% [markdown]
#  # Eliminating all date variables

# %%
loan.drop(["earliest_cr_line", "last_pymnt_d", "next_pymnt_d","last_credit_pull_d"], axis = 1, inplace = True)  # keeping "issue_d" for sorting the train and test

# %%
loan.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months     10.65       162.87
# 1     2500.0       2500.0           2500.0   60 months     15.27        59.83
# 2     2400.0       2400.0           2400.0   36 months     15.96        84.33
# 3    10000.0      10000.0          10000.0   36 months     13.49       339.31
# 4     3000.0       3000.0           3000.0   60 months     12.69        67.79
#
#   grade sub_grade                 emp_title emp_length home_ownership  \
# 0     B        B2                       NaN  10+ years           RENT
# 1     C        C4                     Ryder   < 1 year           RENT
# 2     C        C5                       NaN  10+ years           RENT
# 3     C        C1       AIR RESOURCES BOARD  10+ years           RENT
# 4     B        B5  University Medical Group     1 year           RENT
#
#    annual_inc verification_status    issue_d         purpose  \
# ...

# %%
loan.loc[loan['emp_length']=='10+ years','emp_len'] = 10
loan.loc[loan['emp_length']=='< 1 year','emp_len'] = .5
loan.loc[loan['emp_length']=='1 year','emp_len'] = 1
loan.loc[loan['emp_length']=='3 years','emp_len'] = 3
loan.loc[loan['emp_length']=='8 years','emp_len'] = 8
loan.loc[loan['emp_length']=='9 years','emp_len'] = 9
loan.loc[loan['emp_length']=='4 years','emp_len'] = 4
loan.loc[loan['emp_length']=='5 years','emp_len'] = 5
loan.loc[loan['emp_length']=='6 years','emp_len'] = 6
loan.loc[loan['emp_length']=='2 years','emp_len'] = 2
loan.loc[loan['emp_length']=='7 years','emp_len'] = 7

# %%
loan.shape
# Out:
# (855969, 44)

# %%
loan.drop(["emp_length"], axis = 1, inplace = True)

# %%
loan.shape
# Out:
# (855969, 43)

# %%
loan.default_ind = loan.default_ind.astype("category")

# %% [markdown]
# # Seperating numerical and categorical data

# %%
num_data = loan.select_dtypes(include = ["int64", "float64"])

# %%
cat_data = loan.drop(num_data, axis = 1)

# %%
print(num_data.shape)
print(cat_data.shape)
# Out:
# (855969, 31)
# (855969, 12)

# %% [markdown]
# # Imputation of null values with appropriate values

# %%
from sklearn.experimental import enable_iterative_imputer   
from sklearn.impute import IterativeImputer

# %%
imputer = IterativeImputer(min_value=0.0,random_state=0, initial_strategy="median")
imputer.fit(num_data)
data_num = np.round(imputer.transform(num_data))
data_num = pd.DataFrame(data_num)
data_num.columns = num_data.columns

# %%
data_num.isnull().sum() #because all values are imputed
# Out:
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# int_rate                      0
# installment                   0
# annual_inc                    0
# dti                           0
# delinq_2yrs                   0
# inq_last_6mths                0
# mths_since_last_delinq        0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                    0
# total_acc                     0
# out_prncp                     0
# out_prncp_inv                 0
# total_pymnt                   0
# total_pymnt_inv               0
# total_rec_prncp               0
# total_rec_int                 0
# total_rec_late_fee            0
# recoveries                    0
# collection_recovery_fee       0
# last_pymnt_amnt               0
# collections_12_mths_ex_med    0
# acc_now_delinq                0
# tot_coll_amt                  0
# tot_cur_bal                   0
# ...

# %%
cat_data = cat_data.fillna(cat_data.mode().iloc[0])

# %%
cat_data.shape
# Out:
# (855969, 12)

# %%
cat_data.isnull().sum()
# Out:
# term                   0
# grade                  0
# sub_grade              0
# emp_title              0
# home_ownership         0
# verification_status    0
# issue_d                0
# purpose                0
# title                  0
# addr_state             0
# initial_list_status    0
# default_ind            0
# dtype: int64

# %%
loan2 = pd.concat([data_num, cat_data], axis = 1)

# %%
loan2.shape
# Out:
# (855969, 43)

# %%
loan2.home_ownership.value_counts()
# Out:
# MORTGAGE    429106
# RENT        342535
# OWN          84136
# OTHER          144
# NONE            45
# ANY              3
# Name: home_ownership, dtype: int64

# %%
#loan2.home_ownership.replace({"OTHER":"Others", "NONE":"Others", "ANY":"Others"}, inplace = True)   # because

# %%
loan2.emp_title.nunique()
# Out:
# 290912

# %%
(loan2.emp_title.value_counts() == 1).sum()
# Out:
# 238890

# %%
loan2.drop(["emp_title"], axis = 1, inplace = True)

# %%
print(loan2.title.nunique())
# Out:
# 60991

# %%
loan2.drop(["title"], axis = 1, inplace = True)

# %%
series = pd.value_counts(loan2.purpose)
series
# Out:
# debt_consolidation    505392
# credit_card           200144
# home_improvement       49956
# other                  40949
# major_purchase         16587
# small_business          9785
# car                     8593
# medical                 8193
# moving                  5160
# vacation                4542
# house                   3513
# wedding                 2280
# renewable_energy         549
# educational              326
# Name: purpose, dtype: int64

# %%
mask = (series/series.sum() * 100).lt(1)

# %%
loan2["purpose"] = np.where(loan2["purpose"].isin(series[mask].index), "other", loan2["purpose"]) #seperating the lesser count values

# %%
loan2.purpose.value_counts()
# Out:
# debt_consolidation    505392
# credit_card           200144
# other                  65512
# home_improvement       49956
# major_purchase         16587
# small_business          9785
# car                     8593
# Name: purpose, dtype: int64

# %%
loan2.grade.value_counts()
# Out:
# B    247998
# C    236855
# A    145665
# D    132802
# E     66448
# F     21328
# G      4873
# Name: grade, dtype: int64

# %%
#loan2.grade = loan2.grade.replace({"F":"E", "G":"E"})

# %% [markdown]
# # Visual data exploration

# %%
data_num.hist(figsize = (15,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000115144A87F0>,
# ...
#       dtype=object)

# %%
corr = data_num.corr()

mask = np.triu(np.ones_like(corr, dtype=np.bool))
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
x_axis_labels = data_num.columns # labels for x-axis
y_axis_labels = data_num.columns # labels for y-axis

ax = sns.heatmap(
    corr, 
    mask=mask,
    cmap=cmap,
    xticklabels=x_axis_labels,
    yticklabels=y_axis_labels,
    annot=True
)

# %%
drop_list = ["funded_amnt_inv", "out_prncp_inv", "total_pymnt", "total_pymnt_inv"]
loan2.drop(drop_list, axis = 1)
# Out:
#         loan_amnt  funded_amnt  int_rate  installment  annual_inc   dti  \
# 0          5000.0       5000.0      11.0        163.0     24000.0  28.0
# 1          2500.0       2500.0      15.0         60.0     30000.0   1.0
# 2          2400.0       2400.0      16.0         84.0     12252.0   9.0
# 3         10000.0      10000.0      13.0        339.0     49200.0  20.0
# 4          3000.0       3000.0      13.0         68.0     80000.0  18.0
# 5          5000.0       5000.0       8.0        156.0     36000.0  11.0
# 6          7000.0       7000.0      16.0        170.0     47004.0  24.0
# 7          3000.0       3000.0      19.0        109.0     48000.0   5.0
# 8          5600.0       5600.0      21.0        152.0     40000.0   6.0
# 9          5375.0       5375.0      13.0        121.0     15000.0  18.0
# 10         6500.0       6500.0      15.0        153.0     72000.0  16.0
# 11        12000.0      12000.0      13.0        403.0     75000.0  11.0
# ...

# %%
data_num.acc_now_delinq.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.95,1.0])
# Out:
# count    855969.000000
# mean          0.004944
# std           0.077333
# min           0.000000
# 0%            0.000000
# 20%           0.000000
# 40%           0.000000
# 50%           0.000000
# 60%           0.000000
# 80%           0.000000
# 95%           0.000000
# 100%         14.000000
# max          14.000000
# Name: acc_now_delinq, dtype: float64

# %%
loan2.drop(["acc_now_delinq"], axis = 1, inplace = True)

# %%
 pd.options.display.float_format = "{:.2f}".format

# %%
data_num.annual_inc.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.95,1.0])
# Out:
# count    855969.00
# mean      75071.19
# std       64264.47
# min           0.00
# 0%            0.00
# 20%       42000.00
# 40%       56000.00
# 50%       65000.00
# 60%       72239.60
# 80%       98541.80
# 95%      150000.00
# 100%    9500000.00
# max     9500000.00
# Name: annual_inc, dtype: float64

# %%
loan2.shape
# Out:
# (855969, 40)

# %%
def remove_outlier(df,col,k=2):
    mean = df[col].mean()
    global df1
    sd = df[col].std()
    final_list = [x for x in df[col] if (x > mean - k * sd)]
    final_list = [x for x in final_list if (x < mean + k * sd )]
    df1 = df.loc[df[col].isin(final_list)] ; print(df1.shape) ; return df1

# %%
loan2 = remove_outlier(loan2, "annual_inc", 3)
# Out:
# (849100, 40)

# %%
sns.distplot(loan2.annual_inc, kde=False, color="r", bins=10)

# %%
loan2.collection_recovery_fee.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.95,1.0])
# Out:
# count   849100.00
# mean         4.95
# std         62.18
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 95%          0.00
# 100%      7002.00
# max       7002.00
# Name: collection_recovery_fee, dtype: float64

# %%
loan2.drop(["collection_recovery_fee"], axis = 1, inplace = True)

# %%
loan2.collections_12_mths_ex_med.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.95,1.0])
# Out:
# count   849100.00
# mean         0.01
# std          0.13
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 95%          0.00
# 100%        20.00
# max         20.00
# Name: collections_12_mths_ex_med, dtype: float64

# %%
loan2.drop(["collections_12_mths_ex_med"], axis = 1, inplace = True)

# %%
loan2.delinq_2yrs.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count   849100.00
# mean         0.31
# std          0.86
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 90%          1.00
# 95%          2.00
# 100%        39.00
# max         39.00
# Name: delinq_2yrs, dtype: float64

# %%
loan2.shape
# Out:
# (849100, 38)

# %%
loan2 = remove_outlier(loan2, "delinq_2yrs", 3)
# Out:
# (826919, 38)

# %%
sns.distplot(loan2.delinq_2yrs, kde=False, bins=10)

# %%
loan2.dti.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count   826919.00
# mean        18.20
# std         17.65
# min          0.00
# 0%           0.00
# 20%         11.00
# 40%         15.00
# 50%         18.00
# 60%         20.00
# 80%         26.00
# 90%         30.00
# 95%         33.00
# 100%      9999.00
# max       9999.00
# Name: dti, dtype: float64

# %%
loan2 = remove_outlier(loan2, "dti", 3)
# Out:
# (826903, 38)

# %%
sns.distplot(loan2.dti, kde=False, color="g", bins=10)

# %%
sns.distplot(loan2.emp_len, kde=False, color="y", bins=10)

# %%
loan2.pub_rec.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.95,1.0])
# Out:
# count   826903.00
# mean         0.19
# std          0.58
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 95%          1.00
# 100%        86.00
# max         86.00
# Name: pub_rec, dtype: float64

# %%
loan2.drop(["pub_rec"],axis = 1, inplace = True)

# %%
loan2.recoveries.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count   826903.00
# mean        47.13
# std        412.12
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 90%          0.00
# 95%          0.00
# 100%     33520.00
# max      33520.00
# Name: recoveries, dtype: float64

# %%
loan2.drop(["recoveries"], axis = 1, inplace = True)

# %%
loan2.revol_bal.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count    826903.00
# mean      16607.16
# std       19209.20
# min           0.00
# 0%            0.00
# 20%        5544.00
# 40%        9602.00
# 50%       11937.00
# 60%       14757.00
# 80%       23788.00
# 90%       33143.00
# 95%       43108.00
# 100%    1039903.00
# max     1039903.00
# Name: revol_bal, dtype: float64

# %%
loan2 = remove_outlier(loan2, "revol_bal", 3)
# Out:
# (815631, 36)

# %%
sns.distplot(loan2.revol_bal, kde=False, color="r", bins=10)

# %%
loan2.revol_util.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count   815631.00
# mean        54.92
# std         23.75
# min          0.00
# 0%           0.00
# 20%         33.00
# 40%         49.00
# 50%         56.00
# 60%         63.00
# 80%         77.00
# 90%         86.00
# 95%         92.00
# 100%       892.00
# max        892.00
# Name: revol_util, dtype: float64

# %%
loan2 = remove_outlier(loan2, "revol_util", 3)
# Out:
# (815590, 36)

# %%
sns.distplot(loan2.revol_util, kde=False, bins=10)

# %%
loan2.tot_coll_amt.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count    815590.00
# mean        224.45
# std       10309.17
# min           0.00
# 0%            0.00
# 20%           0.00
# 40%           0.00
# 50%           0.00
# 60%           0.00
# 80%          17.00
# 90%         255.00
# 95%         569.00
# 100%    9152545.00
# max     9152545.00
# Name: tot_coll_amt, dtype: float64

# %%
loan2 = remove_outlier(loan2, "tot_coll_amt", 3)
# Out:
# (815168, 36)

# %%
sns.distplot(loan2.tot_coll_amt, kde=False, color="y", bins=10)

# %%
loan2.drop(["tot_coll_amt"], axis = 1, inplace = True)

# %%
loan2.tot_cur_bal.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count    815168.00
# mean     129796.90
# std      131740.50
# min           0.00
# 0%            0.00
# 20%       25181.00
# 40%       53097.00
# 50%       81354.50
# 60%      123290.00
# 80%      223064.60
# 90%      308351.00
# 95%      389699.30
# 100%    2302431.00
# max     2302431.00
# Name: tot_cur_bal, dtype: float64

# %%
loan2 =  remove_outlier(loan2, "tot_cur_bal", 3)
# Out:
# (802981, 35)

# %%
sns.distplot(loan2.tot_cur_bal, kde=False, color="g", bins=10)

# %%
loan2.total_rec_late_fee.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count   802981.00
# mean         0.31
# std          3.52
# min          0.00
# 0%           0.00
# 20%          0.00
# 40%          0.00
# 50%          0.00
# 60%          0.00
# 80%          0.00
# 90%          0.00
# 95%          0.00
# 100%       359.00
# max        359.00
# Name: total_rec_late_fee, dtype: float64

# %%
loan2.drop(["total_rec_late_fee"], axis = 1, inplace = True)

# %%
loan2.total_rev_hi_lim.describe(percentiles = [0.0,0.2,0.4,0.6,0.8,0.9,0.95,1.0])
# Out:
# count    802981.00
# mean      29255.73
# std       22881.28
# min           0.00
# 0%            0.00
# 20%       12100.00
# 40%       19300.00
# 50%       23500.00
# 60%       28300.00
# 80%       42600.00
# 90%       57200.00
# 95%       72500.00
# 100%    1069400.00
# max     1069400.00
# Name: total_rev_hi_lim, dtype: float64

# %%
loan2 =  remove_outlier(loan2, "total_rev_hi_lim", 3)
# Out:
# (789610, 34)

# %%
sns.distplot(loan2.total_rev_hi_lim, kde=False, color="purple", bins=10)

# %%
loan2.shape
# Out:
# (789610, 34)

# %%
loan3 = loan2.copy()

# %%
data_num2 = loan2.select_dtypes(include = ["int64", "float64"])    # taking out numerical columns

# %%
data_num2.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  annual_inc  \
# 0    5000.00      5000.00          4975.00     11.00       163.00    24000.00
# 1    2500.00      2500.00          2500.00     15.00        60.00    30000.00
# 2    2400.00      2400.00          2400.00     16.00        84.00    12252.00
# 3   10000.00     10000.00         10000.00     13.00       339.00    49200.00
# 4    3000.00      3000.00          3000.00     13.00        68.00    80000.00
#
#     dti  delinq_2yrs  inq_last_6mths  mths_since_last_delinq  open_acc  \
# 0 28.00         0.00            1.00                   42.00      3.00
# 1  1.00         0.00            5.00                   43.00      3.00
# 2  9.00         0.00            2.00                   43.00      2.00
# 3 20.00         0.00            1.00                   35.00     10.00
# 4 18.00         0.00            0.00                   38.00     15.00
#
# ...

# %%
loan3 = loan2.drop(data_num2, axis = 1)

# %% [markdown]
# # Fixing skewed variable by transformation

# %%
ax = data_num2.loc[:, ( (data_num2.skew() > 1) | (data_num2.skew() < -1) )] # seperating highly skewed columns

# %%
ax.shape
# Out:
# (789610, 12)

# %%
ax.skew()
# Out:
# annual_inc         1.49
# delinq_2yrs        2.37
# inq_last_6mths     1.69
# open_acc           1.18
# revol_bal          1.48
# total_pymnt        1.78
# total_pymnt_inv    1.78
# total_rec_prncp    1.90
# total_rec_int      2.85
# last_pymnt_amnt    3.39
# tot_cur_bal        1.18
# total_rev_hi_lim   1.16
# dtype: float64

# %%
data_num2.drop(ax, axis = 1, inplace = True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
ax = ax.apply(lambda x : np.cbrt(x))

# %%
ax.skew()
# Out:
# annual_inc          0.41
# delinq_2yrs         1.83
# inq_last_6mths      0.41
# open_acc            0.18
# revol_bal          -0.07
# total_pymnt         0.16
# total_pymnt_inv     0.16
# total_rec_prncp     0.33
# total_rec_int       0.43
# last_pymnt_amnt     1.81
# tot_cur_bal         0.17
# total_rev_hi_lim   -0.28
# dtype: float64

# %%
data_num2 = pd.concat([data_num2, ax], axis = 1)

# %%
data_num2.shape
# Out:
# (789610, 24)

# %%
loan3.shape
# Out:
# (789610, 10)

# %%
loan3.head()
# Out:
#          term grade sub_grade home_ownership verification_status    issue_d  \
# 0   36 months     B        B2           RENT            Verified 2011-12-01
# 1   60 months     C        C4           RENT     Source Verified 2011-12-01
# 2   36 months     C        C5           RENT        Not Verified 2011-12-01
# 3   36 months     C        C1           RENT     Source Verified 2011-12-01
# 4   60 months     B        B5           RENT     Source Verified 2011-12-01
#
#           purpose addr_state initial_list_status default_ind
# 0     credit_card         AZ                   f           0
# 1             car         GA                   f           1
# 2  small_business         IL                   f           0
# 3           other         CA                   f           0
# 4           other         OR                   f           0

# %% [markdown]
# ## EDA (categorical-data)

# %%
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
loan3.term = le.fit_transform(loan3.term)
loan3.grade = le.fit_transform(loan3.grade)
loan3.sub_grade = le.fit_transform(loan3.sub_grade)
loan3.home_ownership = le.fit_transform(loan3.home_ownership)
loan3.verification_status = le.fit_transform(loan3.verification_status)
loan3.purpose = le.fit_transform(loan3.purpose)
loan3.addr_state = le.fit_transform(loan3.addr_state)
loan3.initial_list_status = le.fit_transform(loan3.initial_list_status)

# %%
caty=loan3.iloc[:,-1]
catx=loan3.iloc[:,:11]

# %%
catx.drop(["issue_d"], axis = 1, inplace = True)

# %%
test=SelectKBest(score_func=chi2,k="all")
fited=test.fit(catx,caty)

# %%
df=pd.DataFrame({"Features":catx.columns,"Imp":list(fited.scores_)})
df
# Out:
#               Features       Imp
# 0                 term    571.09
# 1                grade  11065.20
# 2            sub_grade  46691.33
# 3       home_ownership    822.05
# 4  verification_status    826.39
# 5              purpose    992.13
# 6           addr_state    635.58
# 7  initial_list_status   4098.36
# 8          default_ind 745295.00

# %%
loan3 = pd.concat([data_num2, loan3], axis = 1)

# %%
loan3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 789610 entries, 0 to 855968
# Data columns (total 34 columns):
# loan_amnt                 789610 non-null float64
# funded_amnt               789610 non-null float64
# funded_amnt_inv           789610 non-null float64
# int_rate                  789610 non-null float64
# installment               789610 non-null float64
# dti                       789610 non-null float64
# mths_since_last_delinq    789610 non-null float64
# revol_util                789610 non-null float64
# total_acc                 789610 non-null float64
# out_prncp                 789610 non-null float64
# out_prncp_inv             789610 non-null float64
# emp_len                   789610 non-null float64
# annual_inc                789610 non-null float64
# delinq_2yrs               789610 non-null float64
# inq_last_6mths            789610 non-null float64
# open_acc                  789610 non-null float64
# ...

# %%
loan3.shape
# Out:
# (789610, 34)

# %% [markdown]
# ## Splitting the data

# %%
loan3 = loan3.sample(frac = 1)

# %%
loan3.shape
# Out:
# (789610, 34)

# %%
loan3.head(5)
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment   dti  \
# 564287   11200.00     11200.00         11200.00     12.00       374.00 11.00
# 168233   10000.00     10000.00         10000.00     15.00       348.00 10.00
# 113189    8000.00      8000.00          8000.00     20.00       295.00 13.00
# 464383   30000.00     30000.00         30000.00     11.00       977.00 15.00
# 711409    5600.00      5600.00          5600.00     13.00       188.00 19.00
#
#         mths_since_last_delinq  revol_util  total_acc  out_prncp  \
# 564287                   42.00       78.00      14.00   10415.00
# 168233                   42.00       77.00      16.00       0.00
# 113189                   82.00       90.00      16.00       0.00
# 464383                   40.00       66.00       9.00   29289.00
# 711409                   42.00       66.00       6.00    4532.00
#
#         out_prncp_inv  emp_len  annual_inc  delinq_2yrs  inq_last_6mths  \
# ...

# %% [markdown]
# # datewise split

# %%
train_df = loan3[loan3['issue_d'] < '2015-6-01']
test_df = loan3[loan3['issue_d'] >= '2015-6-01']

# %%
train_df.shape
# Out:
# (556663, 33)

# %%
test_df.shape
# Out:
# (232947, 33)

# %%
train_df.drop(["issue_d"], axis = 1, inplace = True)
test_df.drop(["issue_d"], axis = 1, inplace = True)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# # Splitting data into x and y

# %%
train_df_x = train_df.loc[:,train_df.columns != "default_ind"] 
train_df_y = train_df.loc[:, "default_ind"]
test_df_x = test_df.loc[:,test_df.columns != "default_ind"] 
test_df_y = test_df.loc[:, "default_ind"]

# %%
print(train_df_x.shape)
print(train_df_y.shape)
print("____________________\n")
print(test_df_x.shape)
print(test_df_y.shape)
# Out:
# (556663, 32)
# (556663,)
# ____________________
#
# (232947, 32)
# (232947,)

# %% [markdown]
# # splitting data for cross validation

# %%
loan3.drop(["issue_d"], axis = 1, inplace = True)

# %%
loan_Tr = loan3.iloc[0:450000,:]
loan_Tr.shape
# Out:
# (450000, 33)

# %%
loan_V1 = loan3.iloc[450000:550000,:]
loan_V1.shape
# Out:
# (100000, 33)

# %%
loan_V2 = loan3.iloc[550000:650000,:]
loan_V2.shape
# Out:
# (100000, 33)

# %%
loan_V3 = loan3.iloc[650000:,:]
loan_V3.shape
# Out:
# (139610, 33)

# %%
## first we will spit the data in x and y 
loan_x = loan_Tr.loc[:,loan_Tr.columns != "default_ind"] 
loan_y = loan_Tr.loc[:, "default_ind"]

# %%
print(loan_x.shape)
print(loan_y.shape)
# Out:
# (450000, 32)
# (450000,)

# %%
## first we will spit the data in x and y 
loan_v1_x = loan_V1.loc[:,loan_V1.columns != "default_ind"] 
loan_v1_y = loan_V1.loc[:, "default_ind"]

# %%
loan_v2_x = loan_V2.loc[:,loan_V2.columns != "default_ind"] 
loan_v2_y = loan_V2.loc[:, "default_ind"]

# %%
loan_v3_x = loan_V3.loc[:,loan_V3.columns != "default_ind"] 
loan_v3_y = loan_V3.loc[:, "default_ind"]

# %%
print(loan_v1_x.shape)
print(loan_v1_y.shape)
print("----------------------------")
print(loan_v2_x.shape)
print(loan_v2_y.shape)
print("----------------------------")
print(loan_v3_x.shape)
print(loan_v3_y.shape)
# Out:
# (100000, 32)
# (100000,)
# ----------------------------
# (100000, 32)
# (100000,)
# ----------------------------
# (139610, 32)
# (139610,)

# %%
loan_Tr.default_ind.value_counts()
# Out:
# 0    424859
# 1     25141
# Name: default_ind, dtype: int64

# %% [markdown]
# ## As their is class imbalance in the response categorical variable we will do the oversampling

# %%
loan_x1 = pd.concat([train_df_x, train_df_y], axis = 1)

# %%
# to seperate defaulter and non-defaulter class
No = loan_x1[loan_x1.default_ind == 0]
Yes = loan_x1[loan_x1.default_ind == 1]

# %%
from sklearn.utils import resample

# %%
## using resample module for oversampling the data
Yes_upsample = resample(Yes, replace = True, n_samples = 300000, random_state = 27)

# %%
upsampled = pd.concat([No, Yes_upsample])

# %%
upsampled.default_ind.value_counts().plot(kind = "bar")

# %%
loan_y1 = upsampled.default_ind

# %%
loan_x1 = upsampled.drop('default_ind', axis = 1)

# %%
print(loan_x1.shape)
print(loan_y1.shape)
# Out:
# (812635, 32)
# (812635,)

# %% [markdown]
# # Oversampling for model where split is not datewise

# %%
loan_x11 = pd.concat([loan_x, loan_y], axis = 1)

# %%
# to seperate defaulter and non-defaulter class
No1 = loan_x11[loan_x11.default_ind == 0]
Yes1 = loan_x11[loan_x11.default_ind == 1]

# %%
## using resample module for oversampling the data
Yes_upsample1 = resample(Yes1, replace = True, n_samples = 300000, random_state = 27)

# %%
upsampled = pd.concat([No1, Yes_upsample1])

# %%
upsampled.default_ind.value_counts().plot(kind = "bar")

# %%
loan_y11 = upsampled.default_ind

# %%
loan_x11 = upsampled.drop('default_ind', axis = 1)

# %%
print(loan_x11.shape)
print(loan_y11.shape)
# Out:
# (724859, 32)
# (724859,)

# %% [markdown]
# ## DECISION TREE

# %% [markdown]
# ## datewise model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(loan_x1, loan_y1)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dt_pred = dtree.predict(test_df_x)

# %%
dt_tab = confusion_matrix(dt_pred, test_df_y)

# %%
dt_tab
# Out:
# array([[ 75173,      5],
#        [157487,    282]], dtype=int64)

# %%
dt_acc = accuracy_score(dt_pred, test_df_y)

# %%
dt_acc
# Out:
# 0.32391488192593165

# %%
print(classification_report(dt_pred, test_df_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      1.00      0.49     75178
#            1       0.98      0.00      0.00    157769
#
#     accuracy                           0.32    232947
#    macro avg       0.65      0.50      0.25    232947
# weighted avg       0.77      0.32      0.16    232947

# %% [markdown]
# ## second model

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(loan_x11, loan_y11)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dt_pred = dtree.predict(test_df_x)

# %%
dt_pred2 = dtree.predict(loan_v2_x)

# %%
dt_tab2 = confusion_matrix(dt_pred2, loan_v2_y)

# %%
dt_tab2

# %%
dt_acc2 = accuracy_score(dt_pred2, loan_v2_y)

# %%
dt_acc2

# %%
print(classification_report(dt_pred2, loan_v2_y))

# %%
dt_pred3 = dtree.predict(loan_v3_x)

# %%
dt_tab3 = confusion_matrix(dt_pred3, loan_v3_y)

# %%
dt_tab3

# %%
dt_acc3 = accuracy_score(dt_pred3, loan_v3_y)

# %%
dt_acc3

# %%
print(classification_report(dt_pred3, loan_v3_y))

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(loan_x1, loan_y1)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfc_pred = rfc.predict(test_df_x)

# %%
fi=rfc.feature_importances_

# %%
to_keep = fi[fi>0.005]; len(to_keep)

# %%
def feat_importance(rfc, df):
    return pd.DataFrame({'cols':df.columns, 'imp':rfc.feature_importances_}).sort_values('imp', ascending=False)

# %%
fi = feat_importance(rfc, loan_v1_x); fi[:10]

# %%
fi.plot('cols', 'imp', figsize=(10,6), legend=False)
plt.style.use("fivethirtyeight")def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
rfc_tab = confusion_matrix(rfc_pred, loan_v1_y)

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(12,7), legend=False)

# %%
plot_fi(fi[:20])

# %%
rfc_tab

# %%
to_keep = fi[fi.imp>0.005].cols; len(to_keep)

# %%
to_fit=loan_x1[to_keep]

# %%
rfc.fit(to_fit, loan_y1)

# %%
X_keep = loan_v1_x[to_keep].copy()
rfc_pred = rfc.predict(X_keep)

# %%
rfc_acc = accuracy_score(rfc_pred, test_df_y)

# %%
rfc_acc
# Out:
# 0.40033140585626775

# %%
print(classification_report(rfc_pred, loan_v1_y))

# %%
rfc_pred2 = rfc.predict(loan_v2_x)

# %%
rfc_tab2 = confusion_matrix(rfc_pred2, loan_v2_y)

# %%
rfc_tab2

# %%
rfc_acc2 = accuracy_score(rfc_pred2, loan_v2_y)

# %%
rfc_acc2

# %%
print(classification_report(rfc_pred2, loan_v2_y))

# %%
rfc_pred3 = rfc.predict(loan_v3_x)

# %%
rfc_tab3 = confusion_matrix(rfc_pred3, loan_v3_y)

# %%
rfc_tab3

# %%
rfc_acc3 = accuracy_score(rfc_pred3, loan_v3_y)

# %%
rfc_acc3

# %%
print(classification_report(rfc_pred3, loan_v3_y))

# %% [markdown]
# ## logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(loan_x1, loan_y1)
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
log_pred = logmodel.predict(test_df_x)

# %%
log_tab = confusion_matrix(log_pred, test_df_y)

# %%
log_tab
# Out:
# array([[212893,     48],
#        [ 19767,    239]], dtype=int64)

# %%
log_acc = accuracy_score(log_pred, test_df_y)

# %%
log_acc
# Out:
# 0.9149377326172906

# %%
print(classification_report(log_pred, test_df_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96    212941
#            1       0.83      0.01      0.02     20006
#
#     accuracy                           0.91    232947
#    macro avg       0.87      0.51      0.49    232947
# weighted avg       0.91      0.91      0.88    232947

# %%
log_pred2 = logmodel.predict(loan_v2_x)

# %%
log_tab2 = confusion_matrix(log_pred2, loan_v2_y)

# %%
log_tab2

# %%
log_acc2 = accuracy_score(log_pred2, loan_v2_y)

# %%
log_acc2

# %%
print(classification_report(log_pred2, loan_v2_y))

# %%
log_pred3 = logmodel.predict(loan_v3_x)

# %%
log_tab3 = confusion_matrix(log_pred3, loan_v3_y)

# %%
log_tab3

# %%
log_acc3 = accuracy_score(log_pred3, loan_v3_y)

# %%
log_acc3

# %%
print(classification_report(log_pred3, loan_v3_y))

# %% [markdown]
# ## to drop those variables which are dependent on future

# %%
print(loan_v1_x1.shape)
print(loan_v1_y.shape)
print("------------------------------")
print(loan_v2_x1.shape)
print(loan_v2_y.shape)
print("----------------------------")
print(loan_v3_x1.shape)
print(loan_v3_y.shape)

# %% [markdown]
# ## Decision Tree model 2

# %%
dtree2 = DecisionTreeClassifier()

# %%
dtree2.fit(loan_x2, loan_y1)

# %%
dt_pred_1 = dtree2.predict(loan_v1_x1)

# %%
dt_tab_1 = confusion_matrix(dt_pred_1, loan_v1_y)

# %%
dt_tab_1

# %%
dt_acc_1 = accuracy_score(dt_pred_1, loan_v1_y)

# %%
dt_acc_1

# %%
print(classification_report(dt_pred_1, loan_v1_y))

# %%
dt_pred2_1 = dtree2.predict(loan_v2_x1)

# %%
dt_tab2_1 = confusion_matrix(dt_pred2_1, loan_v2_y)

# %%
dt_tab2_1

# %%
dt_acc2_1 = accuracy_score(dt_pred2_1, loan_v2_y)

# %%
dt_acc2_1

# %%
print(classification_report(dt_pred2_1, loan_v2_y))

# %%
dt_pred3_1 = dtree2.predict(loan_v3_x1)

# %%
dt_tab3_1 = confusion_mat;[rix(dt_pred3_1, loan_v3_y)

# %%
dt_tab3_1

# %%
dt_acc3_1 = accuracy_score(dt_pred3_1, loan_v3_y)

# %%
dt_acc3_1

# %%
print(classification_report(dt_pred3_1, loan_v3_y))

# %% [markdown]
# ## Random Forest model 2

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc2 = RandomForestClassifier()

# %%
rfc2.fit(loan_x2, loan_y1)

# %%
rfc_pred_1 = rfc2.predict(loan_v1_x1)

# %%
rfc_tab_1 = confusion_matrix(rfc_pred_1, loan_v1_y)

# %%
rfc_tab_1

# %%
rfc_acc_1 = accuracy_score(rfc_pred_1, loan_v1_y)

# %%
rfc_acc_1

# %%
print(classification_report(rfc_pred_1, loan_v1_y))

# %%
rfc_pred2_1 = rfc2.predict(loan_v2_x1)

# %%
rfc_tab2_1 = confusion_matrix(rfc_pred2_1, loan_v2_y)

# %%
rfc_tab2_1

# %%
rfc_acc2_1 = accuracy_score(rfc_pred2_1, loan_v2_y)

# %%
rfc_acc2_1

# %%
print(classification_report(rfc_pred2_1, loan_v2_y))

# %%
rfc_pred3_1 = rfc2.predict(loan_v3_x1)

# %%
rfc_tab3_1 = confusion_matrix(rfc_pred3_1, loan_v3_y)

# %%
rfc_tab3_1

# %%
rfc_acc3_1 = accuracy_score(rfc_pred3_1, loan_v3_y)

# %%
rfc_acc3_1

# %%
print(classification_report(rfc_pred3_1, loan_v3_y))

# %% [markdown]
# ## Logistic Regression Model 2

# %%
logmodel2 = LogisticRegression()

# %%
logmodel2.fit(loan_x2, loan_y1)

# %%
log_pred_1 = logmodel2.predict(loan_v1_x1)

# %%
log_tab_1 = confusion_matrix(log_pred_1, loan_v1_y)

# %%
log_tab_1

# %%
log_acc_1 = accuracy_score(log_pred_1, loan_v1_y)

# %%
log_acc_1

# %%
print(classification_report(log_pred_1, loan_v1_y))

# %%
log_pred2_1 = logmodel2.predict(loan_v2_x1)

# %%
log_tab2_1 = confusion_matrix(log_pred2_1, loan_v2_y)

# %%
log_tab2_1

# %%
log_acc2_1 = accuracy_score(log_pred2_1, loan_v2_y)

# %%
log_acc2_1

# %%
print(classification_report(log_pred2_1, loan_v2_y))

# %%
log_pred3_1 = logmodel2.predict(loan_v3_x1)

# %%
log_tab3_1 = confusion_matrix(log_pred3_1, loan_v3_y)

# %%
log_tab3_1

# %%
log_acc3_1 = accuracy_score(log_pred3_1, loan_v3_y)

# %%
log_acc3_1

# %%
print(classification_report(log_pred3, loan_v3_y))

# %% [markdown]
# ## Logistic Regression model 3 with threshold value

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
logpred_prob = logmodel2.predict_proba(loan_v1_x1)

# %%
logpred_prob1 = logpred_prob[:,1]

# %%
roc_log = roc_auc_score(loan_v1_y, logpred_prob1)
print(roc_log)

# %%
fpr, tpr, thresholds = roc_curve(loan_v1_y, logpred_prob1)

# %%
662*+2plt.plot(fpr,tpr)
plt.plot([0,1], [0,1], linestyle = "--")

# %%
threshold_max = thresholds[np.argmax(tpr-fpr)]

# %%
threshold_max

# %%
logpred_prob2 = np.where(logpred_prob[:,1] > threshold_max, 1, 0)

# %%
logtab6 = confusion_matrix(logpred_prob2, loan_v1_y)

# %%
logtab6

# %%
logacc6 = accuracy_score(logpred_prob2, loan_v1_y)

# %%
logacc6

# %%
print(classification_report(logpred_prob2, loan_v1_y))

# %% [markdown]
# ## test2

# %%
logpred_prob_1 = logmodel2.predict_proba(loan_v2_x1)

# %%
logpred_prob1_1 = logpred_prob_1[:,1]

# %%
roc_log_1 = roc_auc_score(loan_v2_y, logpred_prob1_1)
print(roc_log_1)

# %%
fpr_1, tpr_1, thresholds_1 = roc_curve(loan_v2_y, logpred_prob1_1)

# %%
plt.plot(fpr_1,tpr_1)
plt.plot([0,1], [0,1], linestyle = "--")

# %%
threshold_max_1 = thresholds_1[np.argmax(tpr_1-fpr_1)]

# %%
threshold_max_1

# %%
logpred_prob2_1 = np.where(logpred_prob_1[:,1] > threshold_max_1, 1, 0)

# %%
logtab6_1 = confusion_matrix(logpred_prob2_1, loan_v2_y)

# %%
logtab6_1

# %%
logacc6_1 = accuracy_score(logpred_prob2_1, loan_v2_y)

# %%
logacc6_1

# %%
print(classification_report(logpred_prob2_1, loan_v2_y))

# %% [markdown]
# ## test3

# %%
logpred_prob_2 = logmodel2.predict_proba(loan_v3_x1)

# %%
logpred_prob1_2 = logpred_prob_2[:,1]

# %%
roc_log_2 = roc_auc_score(loan_v3_y, logpred_prob1_2)
print(roc_log_2)

# %%
fpr_2, tpr_2, thresholds_2 = roc_curve(loan_v3_y, logpred_prob1_2)

# %%
plt.plot(fpr_2,tpr_2)
plt.plot([0,1], [0,1], linestyle = "--")

# %%
threshold_max_2 = thresholds_2[np.argmax(tpr_2-fpr_2)]

# %%
threshold_max_2

# %%
logpred_prob2_2 = np.where(logpred_prob_2[:,1] > threshold_max_2, 1, 0)

# %%
logtab6_2 = confusion_matrix(logpred_prob2_2, loan_v3_y)

# %%
logtab6_2

# %%
logacc6_2 = accuracy_score(logpred_prob2_2, loan_v3_y)

# %%
logacc6_2

# %%
print(classification_report(logpred_prob2_2, loan_v3_y))
